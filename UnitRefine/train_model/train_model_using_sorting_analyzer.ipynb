# %% [markdown]
# # Training a model for automated curation
#
# If the pretrained models do not give satisfactory performance on your data, it is easy to train your own classifier using SpikeInterface.

# %%
# %pip install spikeinterface[full]
# Out:
# Requirement already satisfied: spikeinterface[full] in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (0.102.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (1.24.0)
# Requirement already satisfied: threadpoolctl>=3.0.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (3.5.0)
# Requirement already satisfied: tqdm in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages\tqdm-4.65.0-py3.9.egg (from spikeinterface[full]) (4.65.0)
# Requirement already satisfied: zarr<2.18,>=2.16 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (2.17.2)
# Requirement already satisfied: neo>=0.13.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (0.13.3)
# Requirement already satisfied: probeinterface>=0.2.23 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (0.2.24)
# Requirement already satisfied: packaging in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages\packaging-23.1-py3.9.egg (from spikeinterface[full]) (23.1)
# Requirement already satisfied: h5py in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (3.8.0)
# Requirement already satisfied: pandas in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (2.2.2)
# Requirement already satisfied: scipy in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (1.10.1)
# Requirement already satisfied: scikit-learn in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (1.5.2)
# Requirement already satisfied: networkx in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (3.1)
# Requirement already satisfied: distinctipy in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (1.2.2)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (3.7.1)
# Requirement already satisfied: cuda-python in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (12.1.0)
# Requirement already satisfied: numba in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (0.57.0)
# Requirement already satisfied: skops in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (0.10.0)
# Requirement already satisfied: huggingface_hub in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from spikeinterface[full]) (0.24.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from matplotlib>=3.6->spikeinterface[full]) (5.12.0)
# Requirement already satisfied: quantities<0.16.0,>=0.14.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages\quantities-0.14.1-py3.9.egg (from neo>=0.13.0->spikeinterface[full]) (0.14.1)
# Requirement already satisfied: asciitree in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from zarr<2.18,>=2.16->spikeinterface[full]) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from zarr<2.18,>=2.16->spikeinterface[full]) (0.11.0)
# Requirement already satisfied: fasteners in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from zarr<2.18,>=2.16->spikeinterface[full]) (0.18)
# Requirement already satisfied: cython in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from cuda-python->spikeinterface[full]) (0.29.34)
# Requirement already satisfied: filelock in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from huggingface_hub->spikeinterface[full]) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from huggingface_hub->spikeinterface[full]) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from huggingface_hub->spikeinterface[full]) (6.0)
# Requirement already satisfied: requests in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from huggingface_hub->spikeinterface[full]) (2.30.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from huggingface_hub->spikeinterface[full]) (4.6.3)
# Requirement already satisfied: colorama in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages\colorama-0.4.6-py3.9.egg (from tqdm->spikeinterface[full]) (0.4.6)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from numba->spikeinterface[full]) (0.40.1rc1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from pandas->spikeinterface[full]) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from pandas->spikeinterface[full]) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from scikit-learn->spikeinterface[full]) (1.4.2)
# Requirement already satisfied: tabulate>=0.8.8 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from skops->spikeinterface[full]) (0.9.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->spikeinterface[full]) (3.15.0)
# Requirement already satisfied: entrypoints in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from numcodecs>=0.10.0->zarr<2.18,>=2.16->spikeinterface[full]) (0.4)
# Requirement already satisfied: six>=1.5 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->spikeinterface[full]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from requests->huggingface_hub->spikeinterface[full]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from requests->huggingface_hub->spikeinterface[full]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from requests->huggingface_hub->spikeinterface[full]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages (from requests->huggingface_hub->spikeinterface[full]) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -andas (c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\jain\anaconda3\envs\spike_interface\lib\site-packages)

# %%
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import spikeinterface.core as si
import spikeinterface.curation as sc
import spikeinterface.widgets as sw


# Note, you can set the number of cores you use using e.g.
# si.set_global_job_kwargs(n_jobs = 8)

# %% [markdown]
# ## Step 1: Generate and label data
#
# For this tutorial, we will use simulated data to create ``recording`` ``sorting`` objects. We'll
# create two sorting objects: :code:`sorting_1` is coupled to the real recording, so will contain good
# units; :code:`sorting_2` is uncoupled, so should produce noise. We'll combine the two into one sorting
# object using :code:`si.aggregate_units`.
#
# (When making your own model, you should
# [load your own recording](https://spikeinterface.readthedocs.io/en/latest/modules/extractors.html)
# and [do a sorting](https://spikeinterface.readthedocs.io/en/latest/modules/sorters.html) on your data.)

# %%
recording, sorting_1 = si.generate_ground_truth_recording(num_channels=4, seed=1, num_units=5)
_, sorting_2 =si.generate_ground_truth_recording(num_channels=4, seed=2, num_units=5)

both_sortings = si.aggregate_units([sorting_1, sorting_2])
# Out:
# Skipping property 'gt_unit_locations' due to shape inconsistency

# %% [markdown]
# The models are based on [quality metrics](https://spikeinterface.readthedocs.io/en/latest/modules/qualitymetrics.html)
# and [template metrics](https://spikeinterface.readthedocs.io/en/latest/modules/postprocessing.html#template-metrics),
# which are computed using a :code:`sorting_analyzer`. So we'll now create a sorting
# analyzer and compute the extensions needed to get the metrics.

# %%
analyzer = si.create_sorting_analyzer(sorting = both_sortings, recording=recording)
analyzer.compute(['noise_levels','random_spikes','waveforms','templates','spike_locations','spike_amplitudes','correlograms','principal_components','quality_metrics','template_metrics'])
# Out:
# estimate_sparsity:   0%|          | 0/10 [00:00<?, ?it/s]
# noise_level:   0%|          | 0/20 [00:00<?, ?it/s]
# compute_waveforms:   0%|          | 0/10 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/10 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/10 [00:00<?, ?it/s]
# Compute : spike_locations + spike_amplitudes:   0%|          | 0/10 [00:00<?, ?it/s]
# noise_level:   0%|          | 0/20 [00:00<?, ?it/s]
# calculate pc_metrics:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Let's plot the templates for the first and fifth units. The first (unit id 0) belongs to
# :code:`sorting_1` so should look like a real unit; the sixth (unit id 5) belongs to :code:`sorting_2`
# so should look like noise.

# %%
sw.plot_unit_templates(analyzer, unit_ids=[0,5])

# %% [markdown]
# This is as expected: great! Find out more about plotting using widgets [here](https://spikeinterface.readthedocs.io/en/latest/modules/widgets.html). The labels
# for our units are then easy to put in a list:

# %%
labels = ['good', 'good', 'good', 'good', 'good', 'bad', 'bad', 'bad', 'bad', 'bad']

# %% [markdown]
# ## Step 2: Train our model
#
# With the labelled data, we can train the model using the :code:`train_model` function.
# Here, the idea is that the trainer will try several classifiers, imputation strategies and
# scaling techniques then save the most accurate. To save time, we'll only try one classifier
# (Random Forest), imputation strategy (median) and scaling technique (standard scaler).

# %%
folder = "my_model"

# We will use a list of one analyzer here, we would strongly advise using more than one to
# improve model performance
trainer = sc.train_model(
    mode = "analyzers", # You can supply a labelled csv file instead of an analyzer
    labels = [labels],
    analyzers = [analyzer],
    folder = folder, # Where to save the model and model_info.json file
    metric_names = None, # Specify which metrics to use for training: by default uses those already calculted
    imputation_strategies = ["median"], # Defaults to all
    scaling_techniques = ["standard_scaler"], # Defaults to all
    classifiers = None, # Default to Random Forest only. Other classifiers you can try [ "AdaBoostClassifier","GradientBoostingClassifier","LogisticRegression","MLPClassifier"]
    overwrite = True, # Whether or not to overwrite `folder` if it already exists. Default is False.
)

best_model = trainer.best_pipeline
# Out:
# Running RandomForestClassifier with imputation median and scaling StandardScaler()
# BayesSearchCV from scikit-optimize not available, using GridSearchCV

# %% [markdown]
# The above code saves the model in ``my_model/model.skops``, some metadata in
# ``my_model/model_info.json`` and the model accuracies in ``model_accuracies.csv``
# in the specified ``folder``.
#
# ``skops`` is a file format: you can think of it as a more-secture pkl file. [Read more](https://skops.readthedocs.io/en/stable/index.html).
#
# The ``model_accuracies.csv`` file contains the accuracy, precision and recall of the
# tested models. Let's take a look

# %%
accuracies = pd.read_csv(Path(folder) / "model_accuracies.csv", index_col = 0)
accuracies.head()
# Out:
#           classifier name imputation_strategy  scaling_strategy  accuracy  \
# 0  RandomForestClassifier              median  StandardScaler()       1.0
#
#    precision  recall  model_id  \
# 0        1.0     1.0         0
#
#                                          best_params
# 0  {'n_estimators': 150, 'min_samples_split': 2, ...

# %% [markdown]
# Our model is perfect!! This is because the task was *very* easy. We had 10 units; where
# half were pure noise and half were not.
#
# The model also contains some more information, such as which features are importantly.
# We can plot these:

# %%
# Plot feature importances
importances = best_model.named_steps['classifier'].feature_importances_
indices = np.argsort(importances)[::-1]

# The sklearn importances are not computed for inputs whose values are all `nan`.
# Hence, we need to pick out the non-`nan` columns of our metrics
features = best_model.feature_names_in_
n_features = best_model.n_features_in_

metrics = pd.concat([analyzer.get_extension('quality_metrics').get_data(), analyzer.get_extension('template_metrics').get_data()], axis=1)
non_null_metrics = ~(metrics.isnull().all()).values

features = features[non_null_metrics]
n_features = len(features)

plt.figure(figsize=(12, 7))
plt.title("Feature Importances")
plt.bar(range(n_features), importances[indices], align="center")
plt.xticks(range(n_features), features[indices], rotation=90)
plt.xlim([-1, n_features])
plt.subplots_adjust(bottom=0.3)
plt.show()
